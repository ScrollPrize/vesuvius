# %% [markdown]
# In this tutorial, we will explore how to load instance annotated volume cubes in Python.
#
# These cubes are created as labels for the training of volumetric segmentation approaches.
# We hope that they will enable machine learning-based models that, even if they don't entirely solve segmentation on their own, perform instance segmentation as a critical first step before the instances are then stitched together into larger sheets!
#
# ### Getting Started:
# First, we need to install and import `vesuvius`, which will help us quickly fetch the cube data from the repository.

# %%
# !pip install vesuvius
# !vesuvius.accept_terms --yes

# %%
import vesuvius
from vesuvius import Cube

# %% [markdown]
# Let's examine which cubes are available on the data repository:

# %%
print(vesuvius.cubes())
# Out:
# {1: {54: {7.91: {'00000_02408_04560': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/00000_02408_04560/', '00064_02664_04304': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/00064_02664_04304/', '00768_02152_03536': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/00768_02152_03536/', '00768_02408_03536': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/00768_02408_03536/', '01024_02152_04048': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01024_02152_04048/', '01024_02152_04304': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01024_02152_04304/', '01744_02000_04048': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02000_04048/', '01744_02000_04304': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02000_04304/', '01744_02000_04560': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02000_04560/', '01744_02000_04816': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02000_04816/', '01744_02256_02768': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02256_02768/', '01744_02256_03792': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02256_03792/', '01744_02256_04048': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02256_04048/', '01744_02256_04304': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02256_04304/', '01744_02256_04560': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02256_04560/', '01744_02256_04816': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02256_04816/', '01744_02512_02768': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02512_02768/', '01744_02512_03024': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02512_03024/', '01744_02512_04048': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02512_04048/', '01744_02512_04304': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02512_04304/', '01744_02512_04560': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02512_04560/', '01744_02512_05072': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02512_05072/', '01744_02768_04048': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/01744_02768_04048/', '02000_02000_02000': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/02000_02000_02000/', '02000_02256_02000': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/02000_02256_02000/', '02000_02256_02256': 'https://dl.ash2txt.org/full-scrolls/Scroll1/PHercParis4.volpkg/seg-volumetric-labels/instance-annotated-cubes/02000_02256_02256/', '0200 ...

# %% [markdown]
# What we observe is a dictionary indexed with scroll number, energy used for the scan (in keV), resolution (in um), and cube indices with z_y_x representing the origin of the reference frame.
#
# Let us access an available cube:

# %%
instance = Cube(scroll_id=1, energy=54, resolution=7.91, z=0, y=2408, x=4560)

# %% [markdown]
# The `Cube` class will download the scroll volume data in addition to the labels:

# %%
volume, mask = instance[:,:,:] # load the data

# %% [markdown]
# Let us plot a slice from both the raw volume and the annotated mask.

# %%
from matplotlib import pyplot as plt

# %%
slice_z = 128  # central slice of a 256x256x256 cube

# %%
# Displaying the 129th slice (index 128) side by side
plt.figure(figsize=(12, 6))

# Plot the volume image
plt.subplot(1, 2, 1)
plt.imshow(volume[slice_z], cmap='gray')
plt.title(f'Volume Slice {slice_z}')
plt.axis('off')  # Hide the axis

# Plot the mask image
plt.subplot(1, 2, 2)
plt.imshow(mask[slice_z], cmap='tab20b')
plt.title(f'Mask Slice {slice_z}')
plt.axis('off')  # Hide the axis

plt.show()

# %% [markdown]
# Fantastic! We are visualizing different instances annotated with different labels (colors)!
#
# We've sliced the cube in a direction that aligns somewhat with the papyrus sheet direction.
# Slicing this on a different axis might show the papyrus sheets more clearly separated:

# %%
slice_y = 128

plt.figure(figsize=(12, 6))

# Plot the volume image
plt.subplot(1, 2, 1)
plt.imshow(volume[:, slice_y, :], cmap='gray')
plt.title(f'Volume Slice {slice_z}')
plt.axis('off')  # Hide the axis

# Plot the mask image
plt.subplot(1, 2, 2)
plt.imshow(mask[:, slice_y, :], cmap='tab20b')
plt.title(f'Mask Slice {slice_z}')
plt.axis('off')  # Hide the axis

plt.show()

# %% [markdown]
# 😍 Beautiful.
#
# As a next step, you could use these volume/mask cube pairs as input to a volumetric segmentation model!
